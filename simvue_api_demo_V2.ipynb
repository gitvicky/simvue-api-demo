# %% [markdown]
# # Demonstration of Simvue's Client API
#
#
# ---

# %% [markdown]
# Processing and Analysing generated simulation data. In this case, we call upon simulation runs that solve the one-dimensional Burgers' Equation. The simulations were previously performed and stored on simvue. In this notebook, we demonstrate how to retrieve run information, including metadata and artifacts. Once we retrieve the information, we perform a dimensionality reduction analysis using PCA, before building a surrogate model to map from the initial and state conditions to the final field state using a Neural Network.

# %% [markdown]
# **The simulation setup for runs setup earlier**
#
# Equation:
# $\frac{\partial u}{\partial t}  + u \frac{\partial u}{\partial x}  = \nu \frac{\partial^2 u}{\partial t^2}, x \in [0, 1] $
#
# Boundary Conditions: Periodic
#
# Initial Distribution :
# $u(x,y,t=0) = sin(\alpha*\pi*x) + np.cos(\beta*\pi*-x) + 1/np.cosh(\gamma*\pi*x) $
#
# where, $\alpha, \beta, \gamma \to [-3,3]^3 $ , sampled using a hypercube.
#
# Initial Velocity Condition :
# $\frac{\partial u}{\partial t}(x,y,t=0) = 0$
#
# Simulations were run by sampling across $\alpha, \beta, \gamma, \nu$ on a supercomputer cluster and stored in the user's allocation in the simvue server within the folder :
#
# ```
# '/API_Demo/Burgers'
# ```

# %%
#Importing the necessary packages
import os
import getpass
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import torch
import torch.nn as nn
import sklearn
from timeit import default_timer
# !pip install simvue
# !pip install simvue==1.0.0.dev1
# !pip install simvue[dataset,plot]==1.0.0.dev3

# Device configuration - Run with GPUs for quicker results
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Collecting simvue[dataset,plot]==1.0.0.dev3
#   Downloading simvue-1.0.0.dev3-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 2.8 MB/s eta 0:00:00
# Collecting PyJWT<3.0.0,>=2.8.0 (from simvue[dataset,plot]==1.0.0.dev3)
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Collecting dill<0.4.0,>=0.3.7 (from simvue[dataset,plot]==1.0.0.dev3)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: msgpack<2.0.0,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from simvue[dataset,plot]==1.0.0.dev3) (1.0.7)
# Collecting psutil<6.0.0,>=5.9.8 (from simvue[dataset,plot]==1.0.0.dev3)
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 36.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3.0.0,>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from simvue[dataset,plot]==1.0.0.dev3) (2.6.1)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from simvue[dataset,plot]==1.0.0.dev3) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from simvue[dataset,plot]==1.0.0.dev3) (8.2.3)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from simvue[dataset,plot]==1.0.0.dev3) (0.10.2)
# Collecting matplotlib[plot]<4.0.0,>=3.8.2 (from simvue[dataset,plot]==1.0.0.dev3)
#   Downloading matplotlib-3.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 69.3 MB/s eta 0:00:00
# Collecting plotly[plot]<6.0.0,>=5.18.0 (from simvue[dataset,plot]==1.0.0.dev3)
#   Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 33.1 MB/s eta 0:00:00
# Collecting numpy[dataset]<2.0.0,>=1.26.3 (from simvue[dataset,plot]==1.0.0.dev3)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 49.6 MB/s eta 0:00:00
# Collecting pandas[dataset]<3.0.0,>=2.2.0 (from simvue[dataset,plot]==1.0.0.dev3)
#   Downloading pandas-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 65.9 MB/s eta 0:00:00
# WARNING: matplotlib 3.8.2 does not provide the extra 'plot'
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (2.8.2)
# WARNING: numpy 1.26.4 does not provide the extra 'dataset'
# WARNING: pandas 2.2.0 does not provide the extra 'dataset'
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas[dataset]<3.0.0,>=2.2.0->simvue[dataset,plot]==1.0.0.dev3) (2023.4)
# Collecting tzdata>=2022.7 (from pandas[dataset]<3.0.0,>=2.2.0->simvue[dataset,plot]==1.0.0.dev3)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 35.3 MB/s eta 0:00:00
# WARNING: plotly 5.18.0 does not provide the extra 'plot'
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.3->simvue[dataset,plot]==1.0.0.dev3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.3->simvue[dataset,plot]==1.0.0.dev3) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.3->simvue[dataset,plot]==1.0.0.dev3) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->simvue[dataset,plot]==1.0.0.dev3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->simvue[dataset,plot]==1.0.0.dev3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->simvue[dataset,plot]==1.0.0.dev3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->simvue[dataset,plot]==1.0.0.dev3) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib[plot]<4.0.0,>=3.8.2->simvue[dataset,plot]==1.0.0.dev3) (1.16.0)
# Installing collected packages: tzdata, PyJWT, psutil, plotly, numpy, dill, pandas, simvue, matplotlib
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# bigframes 0.20.1 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.0 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.0 which is incompatible.
# Successfully installed PyJWT-2.8.0 dill-0.3.8 matplotlib-3.8.2 numpy-1.26.4 pandas-2.2.0 plotly-5.18.0 psutil-5.9.8 simvue-1.0.0.dev3 tzdata-2024.1

# %% [markdown]
# ###Loading Simvue credentials

# %%
os.environ['SIMVUE_URL'] = 'https://dev02.simvue.io'
os.environ['SIMVUE_TOKEN'] = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6InZpZ25lc2giLCJ0ZW5hbnQiOiJlSnFDWDZEVlVVaUVndWRQdnlOcmR6IiwibWFuYWdlciI6ZmFsc2UsImFkbWluIjpmYWxzZSwiZXhwIjoxNzEyNTYyODMyfQ.cm61MHYzYB7y1WDIquWiSoII7NYYgiVv3g7eNLzqcHs'
# os.environ['SIMVUE_TOKEN'] = getpass.getpass(prompt='Token: ')

# %%
#Loading the client module from simvue to extract data using the simvue API
from simvue import Client
client = Client()

# %%
#Obtaining runs from the directory in the simvue server.
run_dict = client.get_runs(['folder.path == /API_Demo/Burgers'], metadata=True)

# %% [markdown]
# Once the run information along with the metadata have been loaded, we iterate over the runs to
# procure the required metadata ($\alpha, \beta, \gamma, \nu$) and the solutions of field evolution stored as artifacts.

# %%
#Retrieve solutions saved as artifacts
run_id = client.get_run_id_from_name('chestnut-exchange')
field_value = client.get_artifact('EyqFZnBQ5ZzQkdmWETc8Sz', 'u_field')

# %%
from matplotlib import pyplot as plt
# from IPython.display import HTML
# !pip install celluloid
# from celluloid import Camera
# Out:
# Collecting celluloid
#   Downloading celluloid-0.2.0-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from celluloid) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->celluloid) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->celluloid) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->celluloid) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->celluloid) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib->celluloid) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->celluloid) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib->celluloid) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->celluloid) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->celluloid) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->celluloid) (1.16.0)
# Installing collected packages: celluloid
# Successfully installed celluloid-0.2.0

# %%
#Extracting all the simulation data
u_sol = []

for ii in tqdm(range(len(run_dict))):
    try:
        u_field = client.get_artifact(run_dict[ii]['id'], 'u_field')
    except:
        pass
    else:
        u_sol.append(u_field)

u_sol = np.asarray(u_sol)
# Out:
# 100%|██████████| 56/56 [02:22<00:00,  2.55s/it]

# %%
#Selecting the initial and final field distributions for the inputs and outputs.
u_initial = u_sol[:, 0, ::100]
u_final = u_sol[:, -1, ::100]

# %% [markdown]
# Having retreived the final states of the field evolution from the simulation runs, we analyse their distribution by performing a dimensionality reduction over the final state of the field, taken from the artifacts. We invoke a PCA from scikit-learn to perform this analysis.

# %%
#Principal Component Analysis to explore the data description
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(u_final.T)
print("Singular Values of the PCA : " + str(pca.singular_values_))
plt.scatter(pca.components_[0], pca.components_[1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
# Out:
# Singular Values of the PCA : [4.55460269 3.74397016]
# Text(0, 0.5, 'Principal Component 2')

# %% [markdown]
# Now, seeing that the data is fairly even distributed, we can construct a simple fully connected neural network to learn the dynamics of the field evolution.

# %%
#Defining a Neural Network to learn the mapping from the Initial and state conditions to the final field evolution.

class MLP(nn.Module):
    def __init__(self, in_features, out_features, num_layers, num_neurons, activation=torch.tanh):
        super(MLP, self).__init__()

        self.in_features = in_features
        self.out_features = out_features
        self.num_layers = num_layers
        self.num_neurons = num_neurons

        self.act_func = activation

        self.layers = nn.ModuleList()

        self.layer_input = nn.Linear(self.in_features, self.num_neurons)

        for ii in range(self.num_layers - 1):
            self.layers.append(nn.Linear(self.num_neurons, self.num_neurons))
        self.layer_output = nn.Linear(self.num_neurons, self.out_features)


    def forward(self, x):

        x_temp = self.act_func(self.layer_input(x))
        for dense in self.layers:
            x_temp = self.act_func(dense(x_temp))
        x_temp = self.layer_output(x_temp)
        return x_temp

# %%
#Setting up the inputs and outputs for the training and test datasets
x = torch.Tensor(u_initial)#Inputs
x = torch.hstack((x, torch.Tensor(u_initial))) #Including the initial distribution to the input
y = torch.Tensor(u_final)#Outputs

train_x = x[:-10].to(device)
train_y = y[:-10].to(device)

test_x = x[-10:].to(device)
test_y = y[-10:].to(device)

# %%
#Defining the model, Loss Function and the optimiser.
configuration = {"Case": 'Burgers',
                 "Field": 'U',
                 "Type": 'MLP',
                 "Epochs":1000,
                 "Optimizer": 'Adam',
                 "Learning Rate": 0.001,
                 "Activation": 'tanh',
                 "Neurons":64,
                 "Layers":10
                 }

model = MLP(20, 10, configuration['Layers'], configuration['Neurons']) #Inputs, Outputs, number of layers, number of neurons
model = model.to(device) #Moving the Model to the GPU
loss_func = torch.nn.MSELoss() #Mean Squared Error Loss
optimizer = torch.optim.Adam(model.parameters(), lr=configuration['Learning Rate']) #Optimizer and features

# %%
#Training the model

from simvue import Run
run = Run(mode='online')
run.init(folder="/API_Demo/Burgers", tags=['Burgers1D', 'NN', 'API Demo'], metadata=configuration)


t1 = default_timer()
num_epochs = configuration['Epochs']
for it in range(num_epochs):
    model.train()
    model_y = model(train_x) #Forward Propagation
    loss = loss_func(model_y, train_y) #Estimating the Loss
    optimizer.zero_grad()
    loss.backward() #Evaluating the gradients via backprop
    optimizer.step() #Applying the gradients

    print('It: %d, Training Loss: %.3e' % (it, loss.item()))

    run.log_metrics({'Train Loss': loss.item()})
t2 = default_timer()
# Out:
# It: 0, Training Loss: 5.134e-01
# It: 1, Training Loss: 4.959e-01
# It: 2, Training Loss: 4.799e-01
# It: 3, Training Loss: 4.644e-01
# It: 4, Training Loss: 4.487e-01
# It: 5, Training Loss: 4.323e-01
# It: 6, Training Loss: 4.149e-01
# It: 7, Training Loss: 3.964e-01
# It: 8, Training Loss: 3.773e-01
# It: 9, Training Loss: 3.586e-01
# It: 10, Training Loss: 3.423e-01
# It: 945, Training Loss: 2.474e-04
# It: 946, Training Loss: 2.471e-04
# It: 947, Training Loss: 2.449e-04
# It: 948, Training Loss: 2.420e-04
# It: 949, Training Loss: 2.391e-04
# It: 950, Training Loss: 2.368e-04
# It: 951, Training Loss: 2.353e-04
# It: 952, Training Loss: 2.342e-04
# It: 953, Training Loss: 2.333e-04
# It: 954, Training Loss: 2.322e-04
# It: 955, Training Loss: 2.310e-04
# It: 956, Training Loss: 2.295e-04
# It: 957, Training Loss: 2.278e-04
# It: 958, Training Loss: 2.262e-04
# It: 959, Training Loss: 2.246e-04
# It: 960, Training Loss: 2.231e-04
# It: 961, Training Loss: 2.216e-04
# It: 962, Training Loss: 2.203e-04
# It: 963, Training Loss: 2.190e-04
# It: 964, Training Loss: 2.178e-04
# It: 965, Training Loss: 2.168e-04
# It: 966, Training Loss: 2.158e-04
# It: 967, Training Loss: 2.148e-04
# It: 968, Training Loss: 2.139e-04
# It: 969, Training Loss: 2.131e-04
# It: 970, Training Loss: 2.124e-04
# It: 971, Training Loss: 2.119e-04
# It: 972, Training Loss: 2.117e-04
# It: 973, Training Loss: 2.122e-04
# It: 974, Training Loss: 2.136e-04
# It: 975, Training Loss: 2.166e-04
# It: 976, Training Loss: 2.222e-04
# It: 977, Training Loss: 2.317e-04
# It: 978, Training Loss: 2.482e-04
# It: 979, Training Loss: 2.740e-04
# It: 980, Training Loss: 3.180e-04
# It: 981, Training Loss: 3.785e-04
# It: 982, Training Loss: 4.755e-04
# It: 983, Training Loss: 5.689e-04
# It: 984, Training Loss: 6.856e-04
# It: 985, Training Loss: 6.938e-04
# It: 986, Training Loss: 6.566e-04
# It: 987, Training Loss: 5.049e-04
# It: 988, Training Loss: 3.591e-04
# It: 989, Training Loss: 2.679e-04
# It: 990, Training Loss: 2.595e-04
# It: 991, Training Loss: 3.287e-04
# It: 992, Training Loss: 4.225e-04
# It: 993, Training Loss: 5.399e-04
# It: 994, Training Loss: 5.259e-04
# It: 995, Training Loss: 5.061e-04
# It: 996, Training Loss: 4.182e-04
# It: 997, Training Loss: 3.938e-04
# It: 998, Training Loss: 4.262e-04
# It: 999, Training Loss: 5.035e-04

# %%
# plot = client.plot_metrics(run.name, "Train Loss", "step")
plot = client.plot_metrics([run.id], ["Train Loss"], "step")

# %%
#Predictions
with torch.no_grad():
    preds = model(test_x).cpu().numpy()

run.update_metadata({'Training_Time': float(t2-t1),
                     'MSE': float(np.mean((preds - test_y.cpu().numpy()))**2)
                    })


from mpl_toolkits.axes_grid1 import make_axes_locatable

#Plotting and comparising the predictions
fig = plt.figure(figsize=(10, 6))
for ii in range(1, 7):
    ax = fig.add_subplot(2,3,ii)
    idx = np.random.randint(0, 10)
    ax.plot(preds[idx], label='Prediction', alpha=0.8,  color = 'navy', linewidth=1)
    ax.plot(test_y[idx].cpu().numpy(), label='Solution', alpha=0.8,  color = 'maroon', linewidth=1)
    plt.title(ii)
    divider = make_axes_locatable(ax)

plt.legend()

run.close()

# %% [markdown]
# Each plot above compares the predicted solution from the neural network to that of the simulation run obtained using the numerical solver for the final state of the field evolution.
